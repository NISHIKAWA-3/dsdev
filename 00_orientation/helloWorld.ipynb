# %%
print("Hello! World!")
# Out:
# Hello! World!

# %% [markdown]
# # レッスン０
# -VS codeの基本的な書き方

# %% [markdown]
# # 見出し1
# ## 見出し2
# ### 見出し3

# %% [markdown]
# __太字__
# _斜体_
# ***太字斜体***

# %% [markdown]
# - 項目1
# - 項目2
#   - サブ項目

# %% [markdown]
# 1. 項目1
# 2. 項目2

# %% [markdown]
# ---

# %% [markdown]
# | 見出し1 | 見出し2 |
# | ------- | ------- |
# | データ1 | データ2 |
# | データ3 | データ4 |

# %%
print("Hello! World!")
print("こんにちは！ 世界！")
# Out:
# Hello! World!
# こんにちは！ 世界！
